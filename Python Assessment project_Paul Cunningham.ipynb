# %% [markdown]
# ## Professional Academy Certificate in Python Programming
# - Coded by Paul Cunningham
# - Due 12 August 2025
# -Lecturer: Vincent McGrady

# %%
#This is a test for code.
print('Assessment for UCD')
# Out:
# Assessment for UCD

# %%
#this is a function that shows an argument and a return.
def describe_python(x, y):
    return f"This is my{x} for {y}."

description = describe_python(" Assessment", "UCD")
print(description)
# Out:
# This is my Assessment for UCD.

# %%
#Import libraries for use in the code.
import math as math

# %%
#This machine will be able to produce various Tayto branded snacks.
class TaytoBelt:
    def __init__ (self, brand, colour, flavour):
        self.brand = brand
        self.colour = colour
        self.flavour = flavour
    

Crisps1 = TaytoBelt("Banshee Bones", "Black", "Salt & Vinegar" )
Crisps2 = TaytoBelt("Hunky Dory's", "Brown", "Buffalo" )
Crisps3 = TaytoBelt("Tayto", "Red",["Cheese & Onion", "Salt & Vinegar", "Smoky Bacon"] )

# %%
#Printing out the outcomes of various definitions results in different outcomes.
print(Crisps1.brand)
print(Crisps2.colour)
print(Crisps3.flavour)
# Out:
# Banshee Bones
# Brown
# ['Cheese & Onion', 'Salt & Vinegar', 'Smoky Bacon']

# %%
print(Crisps3.flavour)
# Out:
# ['Cheese & Onion', 'Salt & Vinegar', 'Smoky Bacon']

# %%
#This variant will be able to deliver crisp packets with certain pack amounts. 
#6 has been added here for a count as a typical multipack contains 6 packs of crisps.

class TaytoBelt:
    count = 6
    
    def __init__ (self, brand, colour, flavour, pack):
        self.brand = brand
        self.colour = colour
        self.flavour = flavour
        self.pack = pack
        
        TaytoBelt.count = TaytoBelt.count
        
    def delivery(self):
        print("Your delivery is on the way. The brand is", self.brand,".Its colour is", self.colour)
        print(TaytoBelt.count)
    

Crisps1 = TaytoBelt("Banshee Bones", "Black", "Salt & Vinegar", 1)
Crisps2 = TaytoBelt("Hunky Dory's", "Brown", "Buffalo", 5)
Crisps3 = TaytoBelt("Tayto", "Red",["Cheese & Onion", "Salt & Vinegar", "Smoky Bacon"], 4)

# %%
#This message will appear detailing the delivery details of the product.

Crisps1.delivery()
Crisps2.delivery()
Crisps3.delivery()
# Out:
# Your delivery is on the way. The brand is Banshee Bones .Its colour is Black
# 6
# Your delivery is on the way. The brand is Hunky Dory's .Its colour is Brown
# 6
# Your delivery is on the way. The brand is Tayto .Its colour is Red
# 6

# %%
#This allows the user to check a count of the number of packets produced.
#This has not gone as intended as Crisps 1, 2 & 3 should have different values.

Crisps1.count
Crisps2.count
Crisps3.count
# Out:
# 6

# %%
#An if statement has been added for a minimum order condition.

# This value can be changed and result in different print outcomes.

order_number = 7

if order_number > 0:
    print(order_number, "Thank you for ordering.")
if order_number > 10:
    print(order_number, "Thats a lot of crisps!")
elif order_number < 0:
    print(order_number, "This is unavailable at this time.")
else:
    print(order_number, "You have no crisps.")
    
#Else conditional did not work out well. Requires tweaking.
# Out:
# 7 Thank you for ordering.
# 7 You have no crisps.

# %%
#Finally the code has a user input command so the user can confirm the order.

print('Please enter your name to confirm order')
x = input()
print('Thank you for ordering crisps from us, '+ x)
# Out:
# Please enter your name to confirm order
# Vincent
# Thank you for ordering crisps from us, Vincent
